# %% [markdown]
# > `Felipe Fernandes - LAIS /PPgEEC /UFRN`

# %% [markdown]
# ---
# # 1.0 Hello, Python!

# %% [markdown]
# <figure>
# <center>
# <figcaption>Guido van Rossum.</figcaption>
# <img width="392" src="https://drive.google.com/uc?id=1Pi3NyGlT3wnDWBy9Jw0artgTgvzvSms9">
# <img width="300" src="https://upload.wikimedia.org/wikipedia/commons/thumb/6/66/Guido_van_Rossum_OSCON_2006.jpg/800px-Guido_van_Rossum_OSCON_2006.jpg">
# </figure>

# %% [markdown]
# ## 1.1 O Python

# %% [markdown]
# O Python é:
#
# > - Simples e fácil de aprender;
# - Alto nível;
# - Sintaxe clara, intuitiva e concisa;
# - Dinamicamente e fortemente tipada;
# - Estrutura simples;
# - Multiparadigma (orientada a objetos, funcional e procedural);
# - Interpretada e compilada;
# - Amplamente utilizada no mercado e comunidade acadêmica:
#   - Google;
#   - Youtube;
#   - Microsoft;
#   - NASA;
#   - Facebook;
#   - Instagram;
#   - Machine Learning;
#   - Data science;
#   - Outr@s.
# - Open source! Free! E possui um comunidade rica.
#
#
# Comparando...
#
# - Linguagem de Programação JAVA:
#
# ```java
# public class Hello{
#   public static void main(String[] args){
#     System.out.println("Hello, World!");
#   }
# }
# ```
#
# - Linguagem de Programação C++:
#
# ```c
# #include <iostream>
#
# int main(){
#   std::cout << "Hello, World!" << std::endl;
#   return 0;
# }
# ```
#
# - Linguagem de Programação Python:
#
# ```python
# print('Hello, World!')
# ```
#
# <figure>
# <center>
# <figcaption>Página da comunidade Pythonista.</figcaption>
# <a href="https://www.python.org/">
# <img width="800" src="https://drive.google.com/uc?id=1-823ZeclkoMM0SODtbNcxcj5A9KbVcE7">
# </figure>

# %% [markdown]
# ## 1.1 Ambientes para o Pythonista

# %% [markdown]
# ### 1.1.1 Modo Interativo

# %% [markdown]
# No modo `interativo` você interage diretamente com o interpretador. Veja o exemplo:
#
# <figure>
# <center>
# <figcaption>IPython Shell.</figcaption>
# <img width="1000" src="https://drive.google.com/uc?id=1AHh3fOVUK40zVIK5AH_XUdoC2EbI40QG">
# </figure>
#
# Como abrir o IPython Shell e escrever algumas instruções? (**let's practice**)
#
# <center><img width="200" alt="creating a repo" src="https://drive.google.com/uc?export=view&id=1G6Lt4G1q3ariS-h0REWpZg4741ROx2Ht"></center>
#
# Para poucas linhas de código o modo `interativo` é trivial. Mas, para códigos maiores, com mais instruções, o modo `interativo` se torna mais complexo.

# %% [markdown]
# ### 1.1.2 Modo Script

# %% [markdown]
# O modo `Script` permite a escrita de uma sequência de instruções, mas não limitande-se somente a uma sequência, sem a interação direta com o interpretador. As instruções podem ser escritas em qualquer editor de texto, como:
#
# - PyCharm
# - Notepad++
# - Sublime Text
# - Visual Studio Code
# - Aton
# - Spyder
#
# Como executar um `Script`? (**let's practice**)
#
# <center><img width="200" alt="creating a repo" src="https://drive.google.com/uc?export=view&id=1G6Lt4G1q3ariS-h0REWpZg4741ROx2Ht"></center>

# %% [markdown]
# ### 1.1.3 Jupyter Notebook e Google Colaboratory

# %% [markdown]
# O `Jupyter Notebook` é uma ferramenta poderosa de código aberto que permite criar e compartilhar documentos com códigos (Python, R, Julia e Scala), equações, imagens, vídeos, \\( \LaTeX\\) e outros (suporte Markdown).
#
# <figure>
# <center>
# <figcaption>Página da comunidade Jupyter.</figcaption>
# <a href="https://jupyter.org/index.html">
# <img width="700" src="https://miro.medium.com/max/1200/1*rBEsEXaC-B6baLCFxGqR4Q.png">
# </figure>

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# <p><img alt="Colaboratory logo" height="45px" src="/img/colab_favicon.ico" align="left" hspace="10px" vspace="0px"></p>
#
# <h1>O que é o Colaboratory?</h1>
#
# O Colaboratory ou "Colab" permite escrever código Python no seu navegador, com:
# - Nenhuma configuração necessária
# - Acesso gratuito a GPUs
# - Compartilhamento fácil
#
# Você pode ser um <strong>estudante</strong>, um <strong>cientista de dados</strong> ou um <strong>pesquisador de IA</strong>, o Colab pode facilitar seu trabalho. Assista ao vídeo <a href="https://www.youtube.com/watch?v=inN8seMm7UI">Introdução ao Colab</a> para saber mais ou clique [AQUI](https://colab.research.google.com/notebooks/intro.ipynb#scrollTo=5fCEDCU_qrC0) e comece a usar o Colab!
#
# Vamos criar o primeiro código no Colab e trabalhar com variáveis e estruturas condicionais. (**let's practice**)
#
# <center><img width="200" alt="creating a repo" src="https://drive.google.com/uc?export=view&id=1G6Lt4G1q3ariS-h0REWpZg4741ROx2Ht"></center>

# %% [markdown]
# # 2.0 Variáveis

# %% [markdown]
# Uma variável é um nome que se refere a um valor.
# - Uma instrução de atribuição cria uma nova variável e dá um valor a ela;
# - Uma área de memória de computador (armazenar os dados) é reservada para a variável.

# %%
# ATENÇÃO PARA O TIPO DA VARIÁVEL (Dinamicamente e fortemente tipada) !!!

mensagem = 'Este é um curso de nivelamento em Python'
n = 2020
pi = 3.141592653589793

# %%
# imprimindo os valores referentes as variáveis
print(mensagem)
print(n)
print(pi)
# Out:
# Este é um curso de nivelamento em Python
# 2020
# 3.141592653589793

# %% [markdown]
# Declaração de variáveis ilegais:

# %%
# é ilegal porque começa com um número
1mensagem = 'Este é um curso de nivelamento em Python'
# Out:
#   File "<ipython-input-21-cc3eb4d42a03>", line 2
#     1mensagem = 'Este é um curso de nivelamento em Python'
#             ^
# SyntaxError: invalid syntax

# %%
# é ilegal porque há um caractere ilegal
n@ = 2020
# Out:
#   File "<ipython-input-22-948288db2a87>", line 2
#     n@ = 2020
#        ^
# SyntaxError: invalid syntax

# %% [markdown]
# Palavras reservadas também não são permitidas para declarar uma variável:
#
# <center><img width="700" alt="creating a repo" src="https://drive.google.com/uc?export=view&id=1k8Gj1lFtvgHt3DYLcNYVTH4GePb_JvKO"></center>

# %% [markdown]
# ## 2.1 Tipos de Variáveis

# %% [markdown]
# ### 2.1.1 Variáveis Numéricas

# %% [markdown]
# Utilizando a função `type()`

# %%
# Verificando o tipo da variável n
print('A variável n de valor {} é do tipo {}'.format(n, type(n)))
# Out:
# A variável n de valor 2020 é do tipo <class 'int'>

# %%
# Verificando o tipo da variável pi
print('A variável pi = {} é do tipo {}'.format(pi, type(pi)))
# Out:
# A variável pi = 3.141592653589793 é do tipo <class 'float'>

# %%
print('A variável mensagem = "{}" é do tipo {}'.format(mensagem, type(mensagem)))
# Out:
# A variável mensagem = "Este é um curso de nivelamento em Python" é do tipo <class 'str'>

# %% [markdown]
# ### 2.1.2 Variáveis Booleanas

# %%
# Declarando e atribuindo valores as variáveis do tipo bool
sinal_vermelho = True
sinal_amarelo = False
sinal_verde = False

# %%
# Imprimindo os valores correspondentes às variáveis
print('Sinal vermelho = {} \nSinal amarelo = {} \nSinal verde = {} '.format(sinal_vermelho, sinal_amarelo, sinal_verde))
# Out:
# Sinal vermelho = True
# Sinal amarelo = False
# Sinal verde = False

# %%
print('A variável "sinal vermelho" é do tipo: {}'.format(type(sinal_vermelho)))
print('A variável "sinal amarelo" é do tipo: {}'.format(type(sinal_amarelo)))
print('A variável "sinal verde" é do tipo: {}'.format(type(sinal_verde)))
# Out:
# A variável "sinal vermelho" é do tipo: <class 'bool'>
# A variável "sinal amarelo" é do tipo: <class 'bool'>
# A variável "sinal verde" é do tipo: <class 'bool'>

# %% [markdown]
# ### 2.1.3 Variáveis String

# %%
# Verificando o tipo da variável mensagem
print('A variável mensagem = "{}" é do tipo {}'.format(mensagem, type(mensagem)))
# Out:
# A variável mensagem = "Este é um curso de nivelamento em Python" é do tipo <class 'str'>

# %% [markdown]
# Existem vários métodos que operam sobre uma string:

# %%
print(mensagem.upper())
# Out:
# ESTE É UM CURSO DE NIVELAMENTO EM PYTHON

# %%
print(mensagem.lower())
# Out:
# este é um curso de nivelamento em python

# %%
print(mensagem)
# Out:
# Este é um curso de nivelamento em Python

# %%
print(mensagem.count('o e')) #observe que não contou o 'é'
# Out:
# 1

# %%
print(mensagem.title())
# Out:
# Este É Um Curso De Nivelamento Em Python

# %% [markdown]
# # 3.0 Operadores

# %% [markdown]
# ### 3.1 Operadores Aritméticos

# %% [markdown]
# | Operadores     |   Operação      | Símbolo matemático |
# |:--------------:|:---------------:|:---------------:|
# | + |        adição       |        +       |
# | - |        subtração       |        -       |
# |* | multiplicação | $\times$ |
# | / | divisão | $\div$ |
# | // | divisão que retorna um inteiro   | $\div$ |
# | ** | exponenciação | $x^y$ |

# %% [markdown]
# > **let's practice!**
#
# - Defina duas variáveis (`x` e `y`) e atribua valores numéricos a elas;
# - Implemente uma instrução utilizando os operadores aritméticos, efetuando uma operação entre as variáveis `x` e `y`, e armazene o resultado da operação a variável `z`;
# - Imprima o resultado de `z`;
# - Verifique o tipo da variável `z`.
#
# <center><img width="200" alt="creating a repo" src="https://drive.google.com/uc?export=view&id=1G6Lt4G1q3ariS-h0REWpZg4741ROx2Ht"></center>

# %%
x = 5
y = 10
z=x**y
print(z)
print(type(z))
# Out:
# 9765625
# <class 'int'>

# %% [markdown]
# ### 3.2 Operadores Relacionais

# %% [markdown]
# | Operadores     |   Operação      | Símbolo matemático |
# |:--------------:|:---------------:|:---------------:|
# |== | Igualdade | $=$|
# |>| Maior que| $>$|
# |<| Menor que|$<$|
# |!=| Diferente |$\neq$|
# |>=| Maior ou igual|$\geq$|
# |<=| Menor ou Igual|$\leq$|
#
# O resultado de uma operação com operadores relacionais é uma expressão booleana, isto é, verdadeiro ou falso.
#
# Vejamos na prática os resultados de operações com operadores relacionais. (**let's practice!**)
#
# - Ainda utilizando as variáveis (já definidas) `x`, `y` e `z`, verifique se:
# ```python
# x < y
# x != y
# (x + y) == z
# ```
# - Imprima os resultados.
#
# <center><img width="200" alt="creating a repo" src="https://drive.google.com/uc?export=view&id=1G6Lt4G1q3ariS-h0REWpZg4741ROx2Ht"></center>

# %%
print(x < y)
print(x != y)
print( (x + y) == z )
# Out:
# True
# True
# False

# %% [markdown]
# ### 3.3 Operadores Lógicos

# %% [markdown]
# | Operadores     |   Operação      | Símbolo matemático |
# |:--------------:|:---------------:|:---------------:|
# |not | não | $\neg$ (negação)|
# |and| e| $\land$ (conjunção)|
# |or| ou|$\lor$ (disjunção)|
#
# A semântica (significado) destes operadores é semelhante ao seu significado em inglês. Por exemplo:
# - `x > 0 and x < 10` só é verdade se `x` for maior que $0$ e menor que $10$.
#
# - `x % 2 == 0 or x % 3 == 0` é verdadeiro se uma ou as duas condição(ões) for(em) verdadeira(s), isto é, se o número for divisível por 2 ou 3.
#   > Nota: o operador módulo, %, divide dois números e devolve o resto.
# - O operador `not` nega uma expressão booleana, então `not(x > y)` é verdade se `x > y` for falso, isto é, se `x` for menor que ou igual a `y`.
#
#
# Execute as expressões acima e imprima os resultados. (**let's practice!**)
#
# <center><img width="200" alt="creating a repo" src="https://drive.google.com/uc?export=view&id=1G6Lt4G1q3ariS-h0REWpZg4741ROx2Ht"></center>

# %%
print(x > y)
print(not(x > y))
# Out:
# False
# True

# %% [markdown]
# ### 3.4 Ordens de Operações

# %% [markdown]
# > São regras que governam a ordem na qual as expressões que envolvem vários operadores e operandos são avaliadas.
#
# - Os Parênteses têm a precedência mais alta e podem ser usados para forçar a avaliação de uma expressão na ordem que você quiser. Como as expressões em parênteses são avaliadas primeiro, `2 * (3-1)` é `4`, e `(1+1)**(5-2)` é `8`. Também é possível usar parênteses para facilitar a leitura de uma expressão, como por exemplo `(x * 100) / 100`, mesmo se o resultado não for alterado.
#
# - A Exponenciação tem a próxima precedência mais alta, então `1 + 2**3` é `9`, não `27`, e `2 * 3**2` é `18`, não `36`.
#
# - A Multiplicação e a Divisão têm precedência mais alta que a Adição e a Subtração. Assim, `2 * 3 - 1` é `5`, não `4`, e `6 + 4 / 2` é `8`, não `5`.
#
# - Os operadores com a mesma precedência são avaliados da esquerda para a direita (exceto na exponenciação). Assim, na expressão `degrees / 2 * pi`, a divisão acontece primeiro e o resultado é multiplicado por `pi`. Para dividir por 2$\pi$, você pode usar parênteses ou escrever `degrees / 2 / pi`.
#
# > NOTA: na dúvida, use os parênteses!

# %% [markdown]
# ### 3.5 Operações com strings

# %% [markdown]
# Em geral, não é possível executar operações matemáticas com strings, mesmo se elas parecerem números, então coisas assim são ilegais:

# %%
'2' - '1'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-c3c854adf3eb> in <module>()
# ----> 1 '2' - '1'
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'

# %%
'eggs' / 'easy'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-79f0f56af3a4> in <module>()
# ----> 1 'eggs' / 'easy'
#
# TypeError: unsupported operand type(s) for /: 'str' and 'str'

# %%
'third' * 'a charm'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-59-588f19ffffca> in <module>()
# ----> 1 'third' * 'a charm'
#
# TypeError: can't multiply sequence by non-int of type 'str'

# %% [markdown]
# Mas há duas exceções, $+$ e $*$. O operador $+$ executa uma CONCATENAÇÃO de strings, ou seja, une as strings pelas extremidades. Por exemplo:

# %%
#Note que no resultado não há espaço entre o nome e o sobrenome.

nome = 'Felipe'
nome_meio = 'Ricardo dos Santos'
sobrenome = 'Fernandes'
print(nome + nome_meio + sobrenome)
# Out:
# FelipeRicardo dos SantosFernandes

# %% [markdown]
# E o operador $*$ executa a repetição. Por exemplo:

# %%
# Se um dos valores for uma string, o outro tem de ser um número inteiro.
var = 'spam'
print(var * 3)
# Out:
# spamspamspam

# %% [markdown]
# # 4.0 Entrada de Teclado (Usuário)

# %% [markdown]
# A função `input` é utilizada para solicitar dados do usuário. O parâmetro que ela recebe é o valor digitado pelo usuário que, geralmente, é atribuído a uma variável.
#
# Exemplos:

# %%
nome = input('Digite seu nome:\n')
idade = int(input('Digite sua idade:\n'))
print('O nome digitado foi {} e a idade {}.'.format(nome, idade))
# Out:
# Digite seu nome:
# Felipe
# Digite sua idade:
# 28
# O nome digitado foi Felipe e a idade 28.

# %% [markdown]
# O que acontece se inserirmos uma string em idade?

# %%
nome = input('Digite seu nome:\n')
idade = input('Digite sua idade:\n')
print('O nome digitado foi {} e a idade {}.'.format(nome, idade))
# Out:
# Digite seu nome:
# Felipe
# Digite sua idade:
# Felipe
# O nome digitado foi Felipe e a idade Felipe.

# %% [markdown]
# Vejamos a conversão de entrada de dados:
#
# ```python
# int( input('texto') )
# float( input('texto') )
# ```

# %%
nome = input('Digite seu nome:\n')
idade = int(input('Digite sua idade:\n'))
print('O nome digitado foi {} e a idade {}.'.format(nome, idade))
# Out:
# Digite seu nome:
# Felipe
# Digite sua idade:
# Felipe
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-74433b20dc20> in <module>()
#       1 nome = input('Digite seu nome:\n')
# ----> 2 idade = int(input('Digite sua idade:\n'))
#       3 print('O nome digitado foi {} e a idade {}.'.format(nome, idade))
#
# ValueError: invalid literal for int() with base 10: 'Felipe'

# %%
nome = input('Digite seu nome:\n')
idade = int(input('Digite sua idade:\n'))
print('O nome digitado foi {} e a idade {}.'.format(nome, idade))
# Out:
# Digite seu nome:
# Felipe
# Digite sua idade:
# 28
# O nome digitado foi Felipe e a idade 28.

# %% [markdown]
# # 5.0 Estruturas Condicionais

# %% [markdown]
# A programação envolve analisar um conjunto de condições e decidir qual ação deve ser executada de acordo com essas condições;
#
# Uma instrução condicional controla o fluxo de execução, dependendo de alguma condição. A instrução permite analisar o estado atual de um programa e responder de forma apropriada a esse estado;
#
# <center><img width="400" alt="creating a repo" src="https://miro.medium.com/max/460/1*TfTJRDghfnemLiXJ7yxrWQ.png"></center>
#
#
# Em Python, a estrutura de decisão (ou seleção) mais simples é a instrução `if`:
#
# ```python
# if <condição>:
#   bloco verdadeiro
# ```
#
# > NOTA: importante manter a endentação do(s) bloco(s)!

# %%
if x < y:
  print("x é maior que y!")
  print("aqui")
  print("oioi")

# %%
a = int (float((input("Digite um ponto flutuante: \n"))))
print(a)
# Out:
# Digite um ponto flutuante:
# 10.5
# 10

# %% [markdown]
# ### 5.1 Exemplos Práticos

# %% [markdown]
# Faça um código capaz de receber do usuário dois valores diferentes e imprimir o maior deles.

# %%
a = int(input('Defina o valor de A\n'))
b = int(input('Agora defina o valor de B, tal que seja diferente de A\n'))

if a > b:
  print('A = {} é maior que B = {}.'.format(a,b))

if b > a:
  print('B = {} é maior que A = {}.'.format(b,a))
# Out:
# Defina o valor de A
# 2
# Agora defina o valor de B, tal que seja diferente de A
# 5
# B = 5 é maior que A = 2.

# %% [markdown]
# Melhorando o código com uma execução alternativa:
#   - Uso da cláusula `else`.
#
# Se a segunda opção for exatamente o inverso da primeira, podemos simplificar da seguinte forma:

# %%
a = int(input('Defina o valor de A\n'))
b = int(input('Agora defina o valor de B, tal que seja diferente de A\n'))

if a > b:
  print('A = {} é maior que B = {}.'.format(a,b))
  print('Um teste')
else:
  print('B = {} é maior que A = {}.'.format(b,a))
# Out:
# Defina o valor de A
# 5
# Agora defina o valor de B, tal que seja diferente de A
# 15
# B = 15 é maior que A = 5.

# %% [markdown]
# ### 5.2 Estruturas Condicionais Encadeadas

# %% [markdown]
# Faça um código capaz de receber do usuário dois valores e imprimir o maior deles ou se são iguais.
#
# > Note, agora há mais de duas possibilidades para serem verificadas.
#
# Vejamos o exemplo:

# %%
a = int(input('Defina o valor de A\n'))
b = int(input('Agora defina o valor de B\n'))

if a > b:
  print('A = {} é maior que B = {}.'.format(a,b))
elif b > a:
    print('B = {} é maior que A = {}.'.format(b,a))
else:
  print('A = {} e B = {} são iguais.'.format(a,b))
# Out:
# Defina o valor de A
# 5
# Agora defina o valor de B
# 2
# A = 5 é maior que B = 2.

# %% [markdown]
# Cada condição é verificada em ordem. Se a primeira for falsa, a próxima é verificada, e assim por diante.

# %% [markdown]
# ### 5.3 Estruturas Condicionais Aninhadas

# %% [markdown]
# Uma condicional também pode ser aninhada dentro de outra. Poderíamos ter escrito o exemplo na seção anterior desta forma:

# %%
a = int(input('Defina o valor de A\n'))
b = int(input('Agora defina o valor de B\n'))

if a == b:
  print('A = {} e B = {} são iguais.'.format(a,b))
else:
  if a > b:
    print('A = {} é maior que B = {}.'.format(a,b))
  else:
    print('B = {} é maior que A = {}.'.format(b,a))
# Out:
# Defina o valor de A
# 10
# Agora defina o valor de B
# 15
# B = 15 é maior que A = 10.

# %% [markdown]
# # 6.0 Exercícios Práticos

# %% [markdown]
# ## Problema 01

# %% [markdown]
# Escreva um programa capaz de receber um valor do usuário referente ao tempo de uma caminhada, em minutos, e o converter para horas. Imprima na tela o resultado da conversão.

# %%
# Escreva aqui seu código!

# %% [markdown]
# ## Problema 02

# %% [markdown]
# Escreva um programa tal que este calcule a média aritmética de um aluno a partir de três notas (`nota1`, `nota2` e `nota3`). O resultado deve exibir a média e a situação (aprovado ou reprovado) do aluno. A nota máxima é 10.0, a mínima é 0.0 e um aluno é aprovado se obtiver média maior ou igual a 5 (cinco).

# %%
# Escreva aqui seu código!

# %% [markdown]
# ## Problema 03

# %% [markdown]
# Escreva um programa que receba como entrada do usuário o valor da Glicemia (mg/dl) e mostre se o usuário necessita de correção: Dose de Insulina (U). Veja a Figura abaixo com os valores referências.
#
# <figure>
# <center>
# <figcaption>Escala convencional de correção de hiperglicemia.</figcaption>
# <img width="350" src="https://drive.google.com/uc?id=1A0MCZHUi40he4Pe9rX6MSFkGCITW_EQc">
# <figcaption>Fonte: Sociedade Brasileira de Diabetes.</figcaption>
# </figure>

# %%
# Escreva aqui seu código!

# %% [markdown]
# # Inserindo Vídeo no Notebook

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('A_MjCqQoLLA')

# %%
from IPython.display import HTML
# https://www.youtube.com/embed/INSERIR_NUM_VIDEO: < buscar ref no link após o "v=" >
HTML('<iframe width="560" height="315" src="https://www.youtube.com/embed/fJ9rUzIMcZQ" frameborder="0" allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>')
# Out:
# <iframe width="560" height="315" src="https://www.youtube.com/embed/fJ9rUzIMcZQ" frameborder="0" allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>

# %%
from IPython.display import HTML
HTML(' COLE AQUI LINK DO VIDEO DO MEET ')

# %% [markdown]
# # Referências
#
# <figure>
# <left>
# <img width="200" src="https://images-na.ssl-images-amazon.com/images/I/71CMylJf8qL.jpg">
# </left>
